# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\uber_data_india_realistic.csv")

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
df.isna().sum()
# Out:
# ride_id                        0
# customer_id                    0
# driver_id                      0
# ride_date                      0
# ride_time                      0
# pickup_location                0
# dropoff_location               0
# distance_km                    0
# ride_duration_min              0
# fare_amount                    0
# payment_method                 0
# customer_rating                0
# driver_rating                  0
# cancellation_reason        71956
# ride_status                    0
# promo_code                 64012
# vehicle_type                   0
# weather_condition              0
# traffic_condition              0
# driver_experience_years        0
# dtype: int64

# %%
df = df.fillna('Not Applicable')

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
df.isna().sum()
# Out:
# ride_id                    0
# customer_id                0
# driver_id                  0
# ride_date                  0
# ride_time                  0
# pickup_location            0
# dropoff_location           0
# distance_km                0
# ride_duration_min          0
# fare_amount                0
# payment_method             0
# customer_rating            0
# driver_rating              0
# cancellation_reason        0
# ride_status                0
# promo_code                 0
# vehicle_type               0
# weather_condition          0
# traffic_condition          0
# driver_experience_years    0
# dtype: int64

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ride_id                  80000 non-null  object
#  1   customer_id              80000 non-null  object
#  2   driver_id                80000 non-null  object
#  3   ride_date                80000 non-null  object
#  4   ride_time                80000 non-null  object
#  5   pickup_location          80000 non-null  object
#  6   dropoff_location         80000 non-null  object
#  7   distance_km              80000 non-null  int64
#  8   ride_duration_min        80000 non-null  float64
#  9   fare_amount              80000 non-null  float64
#  10  payment_method           80000 non-null  object
#  11  customer_rating          80000 non-null  int64
#  12  driver_rating            80000 non-null  int64
#  13  cancellation_reason      80000 non-null  object
# ...

# %%
df['pickup_location'].unique()
# Out:
# array(['Kolkata', 'Delhi', 'Pune', 'Hyderabad', 'Surat', 'Jaipur',
#        'Mumbai', 'Chennai', 'Bangalore', 'Ahmedabad'], dtype=object)

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#Average time duration from Delhi to Hyderabad

# %%
y = df[(df['pickup_location'] == 'Delhi') & (df['dropoff_location'] == 'Hyderabad')]

# %%
y['ride_duration_min'].mean()
# Out:
# 2522.786442812172

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#Finding percentage of cash as payment

# %%
cash_payment = df[df['payment_method'] == 'Cash'].shape[0]

# %%
cash_payment
# Out:
# 26707

# %%
totalpayment = df['payment_method'].count()

# %%
totalpayment
# Out:
# 80000

# %%
cash_per = (cash_payment / totalpayment)*100

# %%
print(cash_per)
# Out:
# 33.38375

# %% [raw]
# so, 33.38% is the cash payment

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#Total cab booking from Ahmedabad

# %%
y = df[df['pickup_location'] == 'Ahmedabad'].shape[0]

# %%
print(y)
# Out:
# 7988

# %% [raw]
# So, 7988 cabs were booked from Ahmedabad

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#Activity: Finding top 5 city to cancel ride

# %%
y = df[df['ride_status'] == 'Cancelled']

# %%
y = y['pickup_location'].value_counts()

# %%
y.sort_values(ascending = 0).head()
# Out:
# pickup_location
# Kolkata      867
# Surat        833
# Ahmedabad    821
# Pune         815
# Hyderabad    806
# Name: count, dtype: int64

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#let's see the reason of ride cancellation

# %%
df['cancellation_reason'].unique()
# Out:
# array(['Not Applicable', 'Rider Cancelled', 'Driver Cancelled', 'No Show'],
#       dtype=object)

# %%
#Top 5 cities where Driver cancelled the ride

# %%
y = df[df['cancellation_reason'] == 'Driver Cancelled']

# %%
y = y['pickup_location'].value_counts()

# %%
y.head()
# Out:
# pickup_location
# Pune         267
# Kolkata      260
# Jaipur       257
# Hyderabad    252
# Surat        250
# Name: count, dtype: int64

# %%
df
# Out:
#         ride_id customer_id driver_id            ride_date ride_time  \
# 0      R0000001      C00001    D00001  2023-01-03 15:00:00  14:05:41
# 1      R0000002      C00002    D00002  2023-01-04 13:00:00  12:26:26
# 2      R0000003      C00003    D00003  2023-01-07 02:00:00  03:25:31
# 3      R0000004      C00004    D00004  2023-01-01 13:00:00  19:43:17
# 4      R0000005      C00005    D00005  2023-01-05 11:00:00  16:35:35
# ...         ...         ...       ...                  ...       ...
# 79995  R0079996      C79996    D79996  2023-01-05 18:00:00  18:08:59
# 79996  R0079997      C79997    D79997  2023-01-08 16:00:00  04:40:39
# 79997  R0079998      C79998    D79998  2023-01-07 14:00:00  14:17:54
# 79998  R0079999      C79999    D79999  2023-01-02 06:00:00  16:46:31
# 79999  R0080000      C80000    D80000  2023-01-01 17:00:00  05:18:32
#
#       pickup_location dropoff_location  distance_km  ride_duration_min  \
# ...

# %%
#top 5 times where most rides start

# %%
 df['ride_time'].value_counts().head()
# Out:
# ride_time
# 23:31:16    8
# 14:01:13    8
# 01:13:45    7
# 02:41:36    7
# 12:15:45    7
# Name: count, dtype: int64
